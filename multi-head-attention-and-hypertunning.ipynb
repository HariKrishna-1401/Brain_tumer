# %%
import tensorflow as tf
import matplotlib.pyplot as plt

data_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    zoom_range=0.2,
    rescale=1/255.0,
    fill_mode='nearest',
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,  
    brightness_range=[0.8, 1.2],
    vertical_flip=False,
)

val_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1/255.0,
)
train_gen = data_gen.flow_from_directory(
    directory="/kaggle/input/brain-tumor-mri-dataset/Training",
    target_size = (224,224),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    color_mode='rgb',
)

test_gen = val_gen.flow_from_directory(
    directory = "/kaggle/input/brain-tumor-mri-dataset/Testing",
    target_size = (224,224),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    color_mode='rgb',
)
# Out:
# 2025-05-06 02:02:09.424301: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746496929.657648      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746496929.726964      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Reshape, Dropout, BatchNormalization, GlobalAveragePooling1D, LayerNormalization, Add
from itertools import product
import numpy as np

# Build Model Function
def build_model(learning_rate, dropout_rate, embed_dim, num_heads):
    input_layer = Input(shape=(224, 224, 3))
    base_model = DenseNet121(include_top=False, weights='imagenet', input_tensor=input_layer)
    base_model.trainable = True

    for layer in base_model.layers[:-40]:  
        layer.trainable = False
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x_1 = Reshape((1, -1))(x)
    x_1 = Dense(embed_dim)(x_1)
    x_residual = x_1
    x_1 = LayerNormalization(epsilon=1e-6)(x_1)

    mha = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim // num_heads)
    x_att = mha(query=x_1, value=x_1, key=x_1)
    x_att = LayerNormalization(epsilon=1e-6)(x_att)
    x_att = Add()([x_att, x_residual])

    x_ffn = Dense(embed_dim, activation='relu')(x_att)
    x_ffn = Dense(embed_dim)(x_ffn)
    x_ffn = LayerNormalization(epsilon=1e-6)(x_ffn)
    x = Add()([x_att, x_ffn])
    x = GlobalAveragePooling1D()(x)
    x = Dropout(dropout_rate)(x)
    x = BatchNormalization()(x)
    x = Dense(64, activation="relu")(x)
    x = Dropout(dropout_rate)(x)
    x = BatchNormalization()(x)
    x = Dense(32, activation="relu")(x)
    output = Dense(4, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    model.compile(
        loss='categorical_crossentropy',
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate, clipnorm=1.0),
        metrics=['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
    )
    return model

learning_rates = [1e-5, 5e-5, 1e-4]
dropout_rates = [0.3, 0.5]
embed_dims = [512, 1024]
num_heads_list = [4, 8]
best_val_loss = float('inf')
best_model = None
best_hparams = {}

for lr, dr, ed, nh in product(learning_rates, dropout_rates, embed_dims, num_heads_list):
    print(f"Training with lr={lr}, dropout={dr}, embed_dim={ed}, num_heads={nh}")
    model = build_model(learning_rate=lr, dropout_rate=dr, embed_dim=ed, num_heads=nh)
    early_stopping = tf.keras.callbacks.EarlyStopping(patience=8, monitor='val_loss', mode='min', restore_best_weights=True)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
    checkpoint = tf.keras.callbacks.ModelCheckpoint(f'model_lr{lr}_dr{dr}_ed{ed}_nh{nh}.keras', monitor='val_loss', save_best_only=True)
    
    history = model.fit(
        train_gen,
        epochs=5,
        batch_size=32,
        validation_data=test_gen,
        callbacks=[early_stopping, reduce_lr, checkpoint]
    )
    
    val_loss = min(history.history['val_loss'])
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model
        best_hparams = {'learning_rate': lr, 'dropout_rate': dr, 'embed_dim': ed, 'num_heads': nh}

print(f"Best hyperparameters: {best_hparams}")
best_model.save('final_best_model.h5')
# Out:
# Training with lr=1e-05, dropout=0.3, embed_dim=512, num_heads=4
# I0000 00:00:1746496948.081853      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 4, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746496992.024429      74 service.cc:148] XLA service 0x7d87102295b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746496992.025433      74 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1746496996.605951      74 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/179 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.2266 - loss: 1.6405 - precision: 0.1951 - recall: 0.0703
# I0000 00:00:1746497016.048905      74 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 210s 834ms/step - accuracy: 0.4240 - loss: 1.2997 - precision: 0.4898 - recall: 0.2674 - val_accuracy: 0.7582 - val_loss: 0.6895 - val_precision: 0.8408 - val_recall: 0.6407 - learning_rate: 1.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 425ms/step - accuracy: 0.6781 - loss: 0.7643 - precision: 0.7706 - recall: 0.5607 - val_accuracy: 0.8101 - val_loss: 0.5675 - val_precision: 0.8590 - val_recall: 0.7529 - learning_rate: 1.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 426ms/step - accuracy: 0.7709 - loss: 0.6081 - precision: 0.8321 - recall: 0.6727 - val_accuracy: 0.8200 - val_loss: 0.5157 - val_precision: 0.8639 - val_recall: 0.7796 - learning_rate: 1.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 426ms/step - accuracy: 0.8056 - loss: 0.5393 - precision: 0.8568 - recall: 0.7288 - val_accuracy: 0.8276 - val_loss: 0.4731 - val_precision: 0.8590 - val_recall: 0.7948 - learning_rate: 1.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 421ms/step - accuracy: 0.8299 - loss: 0.4797 - precision: 0.8693 - recall: 0.7808 - val_accuracy: 0.8360 - val_loss: 0.4443 - val_precision: 0.8660 - val_recall: 0.8185 - learning_rate: 1.0000e-05
# Training with lr=1e-05, dropout=0.3, embed_dim=512, num_heads=8
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 8, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 170s 648ms/step - accuracy: 0.4248 - loss: 1.3205 - precision: 0.4997 - recall: 0.2443 - val_accuracy: 0.7376 - val_loss: 0.6503 - val_precision: 0.8087 - val_recall: 0.6545 - learning_rate: 1.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 438ms/step - accuracy: 0.7087 - loss: 0.7346 - precision: 0.8087 - recall: 0.5821 - val_accuracy: 0.7902 - val_loss: 0.5488 - val_precision: 0.8323 - val_recall: 0.7384 - learning_rate: 1.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 435ms/step - accuracy: 0.8083 - loss: 0.5481 - precision: 0.8752 - recall: 0.7268 - val_accuracy: 0.8207 - val_loss: 0.4891 - val_precision: 0.8488 - val_recall: 0.7750 - learning_rate: 1.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 433ms/step - accuracy: 0.8375 - loss: 0.4839 - precision: 0.8858 - recall: 0.7747 - val_accuracy: 0.8337 - val_loss: 0.4489 - val_precision: 0.8635 - val_recall: 0.7963 - learning_rate: 1.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 436ms/step - accuracy: 0.8472 - loss: 0.4553 - precision: 0.8829 - recall: 0.7987 - val_accuracy: 0.8368 - val_loss: 0.4310 - val_precision: 0.8663 - val_recall: 0.8055 - learning_rate: 1.0000e-05
# Training with lr=1e-05, dropout=0.3, embed_dim=1024, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 179s 670ms/step - accuracy: 0.5380 - loss: 1.0687 - precision: 0.6474 - recall: 0.3918 - val_accuracy: 0.7918 - val_loss: 0.5388 - val_precision: 0.8297 - val_recall: 0.7544 - learning_rate: 1.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 437ms/step - accuracy: 0.8049 - loss: 0.5533 - precision: 0.8600 - recall: 0.7320 - val_accuracy: 0.8413 - val_loss: 0.4298 - val_precision: 0.8682 - val_recall: 0.8093 - learning_rate: 1.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 82s 440ms/step - accuracy: 0.8542 - loss: 0.4516 - precision: 0.8926 - recall: 0.8020 - val_accuracy: 0.8375 - val_loss: 0.4190 - val_precision: 0.8635 - val_recall: 0.8108 - learning_rate: 1.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 436ms/step - accuracy: 0.8693 - loss: 0.4062 - precision: 0.8990 - recall: 0.8236 - val_accuracy: 0.8680 - val_loss: 0.3532 - val_precision: 0.8944 - val_recall: 0.8467 - learning_rate: 1.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 432ms/step - accuracy: 0.8798 - loss: 0.3699 - precision: 0.9066 - recall: 0.8407 - val_accuracy: 0.8604 - val_loss: 0.3556 - val_precision: 0.8862 - val_recall: 0.8314 - learning_rate: 1.0000e-05
# Training with lr=1e-05, dropout=0.3, embed_dim=1024, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 178s 669ms/step - accuracy: 0.5384 - loss: 1.1159 - precision: 0.6333 - recall: 0.4169 - val_accuracy: 0.8154 - val_loss: 0.5051 - val_precision: 0.8446 - val_recall: 0.7796 - learning_rate: 1.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 82s 442ms/step - accuracy: 0.8099 - loss: 0.5397 - precision: 0.8577 - recall: 0.7385 - val_accuracy: 0.8467 - val_loss: 0.4207 - val_precision: 0.8761 - val_recall: 0.8146 - learning_rate: 1.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 82s 444ms/step - accuracy: 0.8403 - loss: 0.4636 - precision: 0.8763 - recall: 0.7914 - val_accuracy: 0.8551 - val_loss: 0.3890 - val_precision: 0.8809 - val_recall: 0.8352 - learning_rate: 1.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 82s 441ms/step - accuracy: 0.8561 - loss: 0.4022 - precision: 0.8921 - recall: 0.8226 - val_accuracy: 0.8604 - val_loss: 0.3624 - val_precision: 0.8801 - val_recall: 0.8398 - learning_rate: 1.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.8747 - loss: 0.3710 - precision: 0.8971 - recall: 0.8374 - val_accuracy: 0.8688 - val_loss: 0.3405 - val_precision: 0.8892 - val_recall: 0.8513 - learning_rate: 1.0000e-05
# Training with lr=1e-05, dropout=0.5, embed_dim=512, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 177s 659ms/step - accuracy: 0.3484 - loss: 1.5003 - precision: 0.3935 - recall: 0.1992 - val_accuracy: 0.7056 - val_loss: 0.8243 - val_precision: 0.8534 - val_recall: 0.4531 - learning_rate: 1.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 438ms/step - accuracy: 0.5747 - loss: 1.0283 - precision: 0.6863 - recall: 0.3937 - val_accuracy: 0.7620 - val_loss: 0.6717 - val_precision: 0.8587 - val_recall: 0.6537 - learning_rate: 1.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.6786 - loss: 0.8272 - precision: 0.7695 - recall: 0.5209 - val_accuracy: 0.7803 - val_loss: 0.6017 - val_precision: 0.8547 - val_recall: 0.7178 - learning_rate: 1.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.7472 - loss: 0.7011 - precision: 0.8256 - recall: 0.6263 - val_accuracy: 0.7948 - val_loss: 0.5540 - val_precision: 0.8579 - val_recall: 0.7414 - learning_rate: 1.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 435ms/step - accuracy: 0.7915 - loss: 0.6425 - precision: 0.8551 - recall: 0.6837 - val_accuracy: 0.8093 - val_loss: 0.5162 - val_precision: 0.8443 - val_recall: 0.7735 - learning_rate: 1.0000e-05
# Training with lr=1e-05, dropout=0.5, embed_dim=512, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 176s 660ms/step - accuracy: 0.2693 - loss: 1.6973 - precision: 0.2873 - recall: 0.1502 - val_accuracy: 0.6949 - val_loss: 0.8994 - val_precision: 0.8748 - val_recall: 0.3677 - learning_rate: 1.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.5031 - loss: 1.1374 - precision: 0.5923 - recall: 0.3541 - val_accuracy: 0.7727 - val_loss: 0.6764 - val_precision: 0.8968 - val_recall: 0.6362 - learning_rate: 1.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.6359 - loss: 0.8975 - precision: 0.7199 - recall: 0.4851 - val_accuracy: 0.7948 - val_loss: 0.5836 - val_precision: 0.8829 - val_recall: 0.6903 - learning_rate: 1.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.6949 - loss: 0.7803 - precision: 0.7775 - recall: 0.5442 - val_accuracy: 0.8238 - val_loss: 0.5289 - val_precision: 0.8907 - val_recall: 0.7269 - learning_rate: 1.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 437ms/step - accuracy: 0.7372 - loss: 0.6895 - precision: 0.8152 - recall: 0.6142 - val_accuracy: 0.8223 - val_loss: 0.4979 - val_precision: 0.8794 - val_recall: 0.7567 - learning_rate: 1.0000e-05
# Training with lr=1e-05, dropout=0.5, embed_dim=1024, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 179s 655ms/step - accuracy: 0.3911 - loss: 1.4090 - precision: 0.4608 - recall: 0.2465 - val_accuracy: 0.7941 - val_loss: 0.6193 - val_precision: 0.8780 - val_recall: 0.6865 - learning_rate: 1.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 435ms/step - accuracy: 0.6748 - loss: 0.8171 - precision: 0.8035 - recall: 0.5273 - val_accuracy: 0.8177 - val_loss: 0.5403 - val_precision: 0.8816 - val_recall: 0.7437 - learning_rate: 1.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 82s 440ms/step - accuracy: 0.7490 - loss: 0.6810 - precision: 0.8379 - recall: 0.6184 - val_accuracy: 0.8337 - val_loss: 0.4962 - val_precision: 0.8927 - val_recall: 0.7742 - learning_rate: 1.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 438ms/step - accuracy: 0.7878 - loss: 0.6060 - precision: 0.8679 - recall: 0.6833 - val_accuracy: 0.8436 - val_loss: 0.4530 - val_precision: 0.8932 - val_recall: 0.8040 - learning_rate: 1.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 435ms/step - accuracy: 0.8222 - loss: 0.5471 - precision: 0.8829 - recall: 0.7255 - val_accuracy: 0.8391 - val_loss: 0.4463 - val_precision: 0.8771 - val_recall: 0.8055 - learning_rate: 1.0000e-05
# Training with lr=1e-05, dropout=0.5, embed_dim=1024, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 177s 654ms/step - accuracy: 0.4282 - loss: 1.3145 - precision: 0.5155 - recall: 0.2611 - val_accuracy: 0.7788 - val_loss: 0.6623 - val_precision: 0.8735 - val_recall: 0.6476 - learning_rate: 1.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 437ms/step - accuracy: 0.6879 - loss: 0.7883 - precision: 0.8038 - recall: 0.5256 - val_accuracy: 0.8093 - val_loss: 0.5662 - val_precision: 0.8568 - val_recall: 0.7346 - learning_rate: 1.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 432ms/step - accuracy: 0.7656 - loss: 0.6455 - precision: 0.8543 - recall: 0.6402 - val_accuracy: 0.8101 - val_loss: 0.5246 - val_precision: 0.8641 - val_recall: 0.7422 - learning_rate: 1.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 431ms/step - accuracy: 0.7935 - loss: 0.5733 - precision: 0.8695 - recall: 0.6893 - val_accuracy: 0.8429 - val_loss: 0.4668 - val_precision: 0.8799 - val_recall: 0.7826 - learning_rate: 1.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 433ms/step - accuracy: 0.8206 - loss: 0.5299 - precision: 0.8848 - recall: 0.7319 - val_accuracy: 0.8596 - val_loss: 0.4195 - val_precision: 0.8895 - val_recall: 0.8108 - learning_rate: 1.0000e-05
# Training with lr=5e-05, dropout=0.3, embed_dim=512, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 178s 661ms/step - accuracy: 0.6208 - loss: 0.9163 - precision: 0.7461 - recall: 0.4733 - val_accuracy: 0.8368 - val_loss: 0.4516 - val_precision: 0.8660 - val_recall: 0.7986 - learning_rate: 5.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 82s 439ms/step - accuracy: 0.8764 - loss: 0.3969 - precision: 0.9037 - recall: 0.8311 - val_accuracy: 0.8879 - val_loss: 0.3262 - val_precision: 0.9059 - val_recall: 0.8665 - learning_rate: 5.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 436ms/step - accuracy: 0.8922 - loss: 0.3338 - precision: 0.9143 - recall: 0.8676 - val_accuracy: 0.8307 - val_loss: 0.4339 - val_precision: 0.8448 - val_recall: 0.8139 - learning_rate: 5.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 437ms/step - accuracy: 0.9010 - loss: 0.2957 - precision: 0.9182 - recall: 0.8839 - val_accuracy: 0.8940 - val_loss: 0.2814 - val_precision: 0.9091 - val_recall: 0.8848 - learning_rate: 5.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.9200 - loss: 0.2631 - precision: 0.9324 - recall: 0.9098 - val_accuracy: 0.8871 - val_loss: 0.2891 - val_precision: 0.9050 - val_recall: 0.8719 - learning_rate: 5.0000e-05
# Training with lr=5e-05, dropout=0.3, embed_dim=512, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 179s 682ms/step - accuracy: 0.5967 - loss: 0.9807 - precision: 0.6803 - recall: 0.4725 - val_accuracy: 0.8192 - val_loss: 0.4891 - val_precision: 0.8479 - val_recall: 0.8040 - learning_rate: 5.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 82s 439ms/step - accuracy: 0.8455 - loss: 0.4580 - precision: 0.8796 - recall: 0.8021 - val_accuracy: 0.8566 - val_loss: 0.3980 - val_precision: 0.8839 - val_recall: 0.8360 - learning_rate: 5.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 435ms/step - accuracy: 0.8929 - loss: 0.3470 - precision: 0.9076 - recall: 0.8683 - val_accuracy: 0.8787 - val_loss: 0.3173 - val_precision: 0.8975 - val_recall: 0.8680 - learning_rate: 5.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 431ms/step - accuracy: 0.9012 - loss: 0.3043 - precision: 0.9168 - recall: 0.8829 - val_accuracy: 0.8917 - val_loss: 0.2956 - val_precision: 0.9079 - val_recall: 0.8802 - learning_rate: 5.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 82s 440ms/step - accuracy: 0.9189 - loss: 0.2581 - precision: 0.9296 - recall: 0.9041 - val_accuracy: 0.9214 - val_loss: 0.2265 - val_precision: 0.9319 - val_recall: 0.9077 - learning_rate: 5.0000e-05
# Training with lr=5e-05, dropout=0.3, embed_dim=1024, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 177s 652ms/step - accuracy: 0.6947 - loss: 0.7873 - precision: 0.7739 - recall: 0.5967 - val_accuracy: 0.8322 - val_loss: 0.4572 - val_precision: 0.8476 - val_recall: 0.8230 - learning_rate: 5.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 435ms/step - accuracy: 0.8662 - loss: 0.3777 - precision: 0.8913 - recall: 0.8378 - val_accuracy: 0.9100 - val_loss: 0.2845 - val_precision: 0.9159 - val_recall: 0.8894 - learning_rate: 5.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 425ms/step - accuracy: 0.8943 - loss: 0.3146 - precision: 0.9153 - recall: 0.8690 - val_accuracy: 0.8833 - val_loss: 0.2932 - val_precision: 0.8982 - val_recall: 0.8749 - learning_rate: 5.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 430ms/step - accuracy: 0.9016 - loss: 0.2860 - precision: 0.9174 - recall: 0.8903 - val_accuracy: 0.8833 - val_loss: 0.2845 - val_precision: 0.8964 - val_recall: 0.8780 - learning_rate: 5.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 431ms/step - accuracy: 0.9259 - loss: 0.2403 - precision: 0.9317 - recall: 0.9121 - val_accuracy: 0.9199 - val_loss: 0.2203 - val_precision: 0.9299 - val_recall: 0.9100 - learning_rate: 5.0000e-05
# Training with lr=5e-05, dropout=0.3, embed_dim=1024, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 179s 666ms/step - accuracy: 0.5920 - loss: 1.0045 - precision: 0.6471 - recall: 0.4809 - val_accuracy: 0.8505 - val_loss: 0.4302 - val_precision: 0.8607 - val_recall: 0.8345 - learning_rate: 5.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 82s 439ms/step - accuracy: 0.8630 - loss: 0.4289 - precision: 0.8914 - recall: 0.8246 - val_accuracy: 0.8673 - val_loss: 0.3730 - val_precision: 0.8771 - val_recall: 0.8490 - learning_rate: 5.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 425ms/step - accuracy: 0.8918 - loss: 0.3413 - precision: 0.9135 - recall: 0.8715 - val_accuracy: 0.9001 - val_loss: 0.2851 - val_precision: 0.9097 - val_recall: 0.8917 - learning_rate: 5.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 417ms/step - accuracy: 0.9056 - loss: 0.2880 - precision: 0.9172 - recall: 0.8891 - val_accuracy: 0.8841 - val_loss: 0.3000 - val_precision: 0.8965 - val_recall: 0.8787 - learning_rate: 5.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 417ms/step - accuracy: 0.9181 - loss: 0.2674 - precision: 0.9250 - recall: 0.9050 - val_accuracy: 0.8871 - val_loss: 0.2953 - val_precision: 0.8969 - val_recall: 0.8757 - learning_rate: 5.0000e-05
# Training with lr=5e-05, dropout=0.5, embed_dim=512, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 171s 632ms/step - accuracy: 0.4541 - loss: 1.2546 - precision: 0.5517 - recall: 0.3074 - val_accuracy: 0.8002 - val_loss: 0.5636 - val_precision: 0.8610 - val_recall: 0.7513 - learning_rate: 5.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 426ms/step - accuracy: 0.7740 - loss: 0.6569 - precision: 0.8636 - recall: 0.6231 - val_accuracy: 0.8558 - val_loss: 0.4238 - val_precision: 0.8817 - val_recall: 0.8185 - learning_rate: 5.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 425ms/step - accuracy: 0.8474 - loss: 0.5021 - precision: 0.8957 - recall: 0.7626 - val_accuracy: 0.8833 - val_loss: 0.3410 - val_precision: 0.9100 - val_recall: 0.8566 - learning_rate: 5.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 422ms/step - accuracy: 0.8800 - loss: 0.4026 - precision: 0.9118 - recall: 0.8331 - val_accuracy: 0.8909 - val_loss: 0.3127 - val_precision: 0.9113 - val_recall: 0.8780 - learning_rate: 5.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 425ms/step - accuracy: 0.9029 - loss: 0.3528 - precision: 0.9240 - recall: 0.8656 - val_accuracy: 0.8940 - val_loss: 0.2900 - val_precision: 0.9099 - val_recall: 0.8780 - learning_rate: 5.0000e-05
# Training with lr=5e-05, dropout=0.5, embed_dim=512, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 172s 649ms/step - accuracy: 0.4560 - loss: 1.3091 - precision: 0.5142 - recall: 0.3131 - val_accuracy: 0.7925 - val_loss: 0.5810 - val_precision: 0.8487 - val_recall: 0.7574 - learning_rate: 5.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 428ms/step - accuracy: 0.7829 - loss: 0.6378 - precision: 0.8507 - recall: 0.6992 - val_accuracy: 0.8345 - val_loss: 0.4894 - val_precision: 0.8492 - val_recall: 0.8116 - learning_rate: 5.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 421ms/step - accuracy: 0.8395 - loss: 0.5073 - precision: 0.8756 - recall: 0.7823 - val_accuracy: 0.8436 - val_loss: 0.4576 - val_precision: 0.8559 - val_recall: 0.8246 - learning_rate: 5.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 426ms/step - accuracy: 0.8743 - loss: 0.4118 - precision: 0.9013 - recall: 0.8377 - val_accuracy: 0.8795 - val_loss: 0.3335 - val_precision: 0.8928 - val_recall: 0.8703 - learning_rate: 5.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 426ms/step - accuracy: 0.9023 - loss: 0.3507 - precision: 0.9227 - recall: 0.8752 - val_accuracy: 0.9115 - val_loss: 0.2565 - val_precision: 0.9211 - val_recall: 0.9077 - learning_rate: 5.0000e-05
# Training with lr=5e-05, dropout=0.5, embed_dim=1024, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 171s 643ms/step - accuracy: 0.5864 - loss: 1.0240 - precision: 0.6941 - recall: 0.4337 - val_accuracy: 0.8284 - val_loss: 0.4867 - val_precision: 0.8571 - val_recall: 0.8055 - learning_rate: 5.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.8489 - loss: 0.4809 - precision: 0.8933 - recall: 0.7884 - val_accuracy: 0.8528 - val_loss: 0.3849 - val_precision: 0.8730 - val_recall: 0.8284 - learning_rate: 5.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 425ms/step - accuracy: 0.8818 - loss: 0.4003 - precision: 0.9123 - recall: 0.8280 - val_accuracy: 0.8940 - val_loss: 0.3099 - val_precision: 0.9055 - val_recall: 0.8841 - learning_rate: 5.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 418ms/step - accuracy: 0.9009 - loss: 0.3334 - precision: 0.9222 - recall: 0.8732 - val_accuracy: 0.8688 - val_loss: 0.3523 - val_precision: 0.8799 - val_recall: 0.8604 - learning_rate: 5.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 438ms/step - accuracy: 0.9121 - loss: 0.3138 - precision: 0.9279 - recall: 0.8927 - val_accuracy: 0.9161 - val_loss: 0.2388 - val_precision: 0.9246 - val_recall: 0.9069 - learning_rate: 5.0000e-05
# Training with lr=5e-05, dropout=0.5, embed_dim=1024, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 175s 659ms/step - accuracy: 0.4901 - loss: 1.1755 - precision: 0.5689 - recall: 0.3455 - val_accuracy: 0.8200 - val_loss: 0.5189 - val_precision: 0.8510 - val_recall: 0.7971 - learning_rate: 5.0000e-05
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 423ms/step - accuracy: 0.8265 - loss: 0.5440 - precision: 0.8806 - recall: 0.7376 - val_accuracy: 0.8642 - val_loss: 0.3855 - val_precision: 0.8824 - val_recall: 0.8528 - learning_rate: 5.0000e-05
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 422ms/step - accuracy: 0.8858 - loss: 0.4236 - precision: 0.9104 - recall: 0.8314 - val_accuracy: 0.8780 - val_loss: 0.3365 - val_precision: 0.8925 - val_recall: 0.8680 - learning_rate: 5.0000e-05
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 424ms/step - accuracy: 0.8921 - loss: 0.3732 - precision: 0.9164 - recall: 0.8555 - val_accuracy: 0.8947 - val_loss: 0.3060 - val_precision: 0.9029 - val_recall: 0.8863 - learning_rate: 5.0000e-05
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 77s 414ms/step - accuracy: 0.9071 - loss: 0.3308 - precision: 0.9235 - recall: 0.8831 - val_accuracy: 0.8856 - val_loss: 0.3166 - val_precision: 0.8981 - val_recall: 0.8810 - learning_rate: 5.0000e-05
# Training with lr=0.0001, dropout=0.3, embed_dim=512, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 171s 637ms/step - accuracy: 0.6251 - loss: 0.9281 - precision: 0.6868 - recall: 0.5134 - val_accuracy: 0.8604 - val_loss: 0.4255 - val_precision: 0.8783 - val_recall: 0.8474 - learning_rate: 1.0000e-04
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 425ms/step - accuracy: 0.8766 - loss: 0.3741 - precision: 0.8969 - recall: 0.8566 - val_accuracy: 0.8764 - val_loss: 0.3377 - val_precision: 0.8875 - val_recall: 0.8604 - learning_rate: 1.0000e-04
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 426ms/step - accuracy: 0.9004 - loss: 0.3034 - precision: 0.9154 - recall: 0.8814 - val_accuracy: 0.9016 - val_loss: 0.2726 - val_precision: 0.9128 - val_recall: 0.8947 - learning_rate: 1.0000e-04
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 427ms/step - accuracy: 0.9290 - loss: 0.2262 - precision: 0.9360 - recall: 0.9178 - val_accuracy: 0.9054 - val_loss: 0.2478 - val_precision: 0.9136 - val_recall: 0.9039 - learning_rate: 1.0000e-04
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 425ms/step - accuracy: 0.9311 - loss: 0.2168 - precision: 0.9380 - recall: 0.9259 - val_accuracy: 0.9344 - val_loss: 0.1692 - val_precision: 0.9394 - val_recall: 0.9222 - learning_rate: 1.0000e-04
# Training with lr=0.0001, dropout=0.3, embed_dim=512, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 176s 662ms/step - accuracy: 0.6608 - loss: 0.8857 - precision: 0.7246 - recall: 0.5470 - val_accuracy: 0.8574 - val_loss: 0.4109 - val_precision: 0.8691 - val_recall: 0.8459 - learning_rate: 1.0000e-04
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 428ms/step - accuracy: 0.8805 - loss: 0.3658 - precision: 0.9023 - recall: 0.8567 - val_accuracy: 0.8833 - val_loss: 0.3280 - val_precision: 0.8922 - val_recall: 0.8780 - learning_rate: 1.0000e-04
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 421ms/step - accuracy: 0.9122 - loss: 0.2695 - precision: 0.9249 - recall: 0.8984 - val_accuracy: 0.9199 - val_loss: 0.2242 - val_precision: 0.9279 - val_recall: 0.9123 - learning_rate: 1.0000e-04
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 422ms/step - accuracy: 0.9226 - loss: 0.2382 - precision: 0.9317 - recall: 0.9151 - val_accuracy: 0.9314 - val_loss: 0.1866 - val_precision: 0.9375 - val_recall: 0.9268 - learning_rate: 1.0000e-04
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 419ms/step - accuracy: 0.9352 - loss: 0.2095 - precision: 0.9412 - recall: 0.9253 - val_accuracy: 0.9329 - val_loss: 0.1730 - val_precision: 0.9419 - val_recall: 0.9268 - learning_rate: 1.0000e-04
# Training with lr=0.0001, dropout=0.3, embed_dim=1024, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 170s 635ms/step - accuracy: 0.6833 - loss: 0.8230 - precision: 0.7384 - recall: 0.6085 - val_accuracy: 0.8139 - val_loss: 0.5968 - val_precision: 0.8227 - val_recall: 0.8070 - learning_rate: 1.0000e-04
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 427ms/step - accuracy: 0.8852 - loss: 0.3544 - precision: 0.9076 - recall: 0.8594 - val_accuracy: 0.9054 - val_loss: 0.2780 - val_precision: 0.9208 - val_recall: 0.8955 - learning_rate: 1.0000e-04
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 77s 417ms/step - accuracy: 0.9146 - loss: 0.2826 - precision: 0.9275 - recall: 0.8942 - val_accuracy: 0.8833 - val_loss: 0.2940 - val_precision: 0.8958 - val_recall: 0.8726 - learning_rate: 1.0000e-04
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 428ms/step - accuracy: 0.9313 - loss: 0.2400 - precision: 0.9419 - recall: 0.9185 - val_accuracy: 0.9130 - val_loss: 0.2310 - val_precision: 0.9230 - val_recall: 0.9047 - learning_rate: 1.0000e-04
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 426ms/step - accuracy: 0.9289 - loss: 0.2204 - precision: 0.9386 - recall: 0.9192 - val_accuracy: 0.9359 - val_loss: 0.1892 - val_precision: 0.9434 - val_recall: 0.9283 - learning_rate: 1.0000e-04
# Training with lr=0.0001, dropout=0.3, embed_dim=1024, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 171s 635ms/step - accuracy: 0.6829 - loss: 0.8010 - precision: 0.7852 - recall: 0.5803 - val_accuracy: 0.8566 - val_loss: 0.4738 - val_precision: 0.8623 - val_recall: 0.8406 - learning_rate: 1.0000e-04
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 427ms/step - accuracy: 0.8726 - loss: 0.3764 - precision: 0.8980 - recall: 0.8422 - val_accuracy: 0.9130 - val_loss: 0.2521 - val_precision: 0.9221 - val_recall: 0.9024 - learning_rate: 1.0000e-04
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 424ms/step - accuracy: 0.9077 - loss: 0.2795 - precision: 0.9224 - recall: 0.8914 - val_accuracy: 0.9161 - val_loss: 0.2355 - val_precision: 0.9240 - val_recall: 0.9085 - learning_rate: 1.0000e-04
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 422ms/step - accuracy: 0.9210 - loss: 0.2294 - precision: 0.9314 - recall: 0.9095 - val_accuracy: 0.9191 - val_loss: 0.2279 - val_precision: 0.9248 - val_recall: 0.9100 - learning_rate: 1.0000e-04
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 426ms/step - accuracy: 0.9397 - loss: 0.1956 - precision: 0.9499 - recall: 0.9314 - val_accuracy: 0.9245 - val_loss: 0.2039 - val_precision: 0.9315 - val_recall: 0.9130 - learning_rate: 1.0000e-04
# Training with lr=0.0001, dropout=0.5, embed_dim=512, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 176s 665ms/step - accuracy: 0.5547 - loss: 1.0432 - precision: 0.6811 - recall: 0.4052 - val_accuracy: 0.8307 - val_loss: 0.4731 - val_precision: 0.8499 - val_recall: 0.8207 - learning_rate: 1.0000e-04
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 77s 414ms/step - accuracy: 0.8494 - loss: 0.4617 - precision: 0.8892 - recall: 0.8010 - val_accuracy: 0.8741 - val_loss: 0.4108 - val_precision: 0.8828 - val_recall: 0.8619 - learning_rate: 1.0000e-04
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 77s 415ms/step - accuracy: 0.8948 - loss: 0.3479 - precision: 0.9141 - recall: 0.8723 - val_accuracy: 0.9039 - val_loss: 0.2864 - val_precision: 0.9154 - val_recall: 0.8909 - learning_rate: 1.0000e-04
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 418ms/step - accuracy: 0.9078 - loss: 0.3030 - precision: 0.9242 - recall: 0.8880 - val_accuracy: 0.9054 - val_loss: 0.2703 - val_precision: 0.9129 - val_recall: 0.9039 - learning_rate: 1.0000e-04
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 431ms/step - accuracy: 0.9248 - loss: 0.2527 - precision: 0.9342 - recall: 0.9103 - val_accuracy: 0.9352 - val_loss: 0.1836 - val_precision: 0.9399 - val_recall: 0.9306 - learning_rate: 1.0000e-04
# Training with lr=0.0001, dropout=0.5, embed_dim=512, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 171s 629ms/step - accuracy: 0.5235 - loss: 1.0900 - precision: 0.6163 - recall: 0.3700 - val_accuracy: 0.8398 - val_loss: 0.4758 - val_precision: 0.8620 - val_recall: 0.8192 - learning_rate: 1.0000e-04
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 420ms/step - accuracy: 0.8476 - loss: 0.4758 - precision: 0.8864 - recall: 0.7950 - val_accuracy: 0.8924 - val_loss: 0.3080 - val_precision: 0.9078 - val_recall: 0.8787 - learning_rate: 1.0000e-04
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 77s 415ms/step - accuracy: 0.8841 - loss: 0.3838 - precision: 0.9058 - recall: 0.8498 - val_accuracy: 0.8818 - val_loss: 0.3313 - val_precision: 0.8918 - val_recall: 0.8741 - learning_rate: 1.0000e-04
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 418ms/step - accuracy: 0.8994 - loss: 0.3232 - precision: 0.9174 - recall: 0.8806 - val_accuracy: 0.9184 - val_loss: 0.2359 - val_precision: 0.9271 - val_recall: 0.9115 - learning_rate: 1.0000e-04
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 421ms/step - accuracy: 0.9235 - loss: 0.2495 - precision: 0.9336 - recall: 0.9043 - val_accuracy: 0.9352 - val_loss: 0.2073 - val_precision: 0.9397 - val_recall: 0.9275 - learning_rate: 1.0000e-04
# Training with lr=0.0001, dropout=0.5, embed_dim=1024, num_heads=4
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 173s 644ms/step - accuracy: 0.5957 - loss: 0.9886 - precision: 0.6836 - recall: 0.4797 - val_accuracy: 0.8551 - val_loss: 0.4296 - val_precision: 0.8647 - val_recall: 0.8436 - learning_rate: 1.0000e-04
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 420ms/step - accuracy: 0.8552 - loss: 0.4594 - precision: 0.8877 - recall: 0.8064 - val_accuracy: 0.7895 - val_loss: 0.6614 - val_precision: 0.7987 - val_recall: 0.7780 - learning_rate: 1.0000e-04
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 437ms/step - accuracy: 0.8878 - loss: 0.3626 - precision: 0.9104 - recall: 0.8629 - val_accuracy: 0.8787 - val_loss: 0.3512 - val_precision: 0.8853 - val_recall: 0.8711 - learning_rate: 1.0000e-04
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 78s 422ms/step - accuracy: 0.9087 - loss: 0.3000 - precision: 0.9224 - recall: 0.8918 - val_accuracy: 0.8841 - val_loss: 0.3666 - val_precision: 0.8887 - val_recall: 0.8772 - learning_rate: 1.0000e-04
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 429ms/step - accuracy: 0.9277 - loss: 0.2504 - precision: 0.9386 - recall: 0.9113 - val_accuracy: 0.9237 - val_loss: 0.2257 - val_precision: 0.9296 - val_recall: 0.9161 - learning_rate: 1.0000e-04
# Training with lr=0.0001, dropout=0.5, embed_dim=1024, num_heads=8
# Epoch 1/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 176s 655ms/step - accuracy: 0.5190 - loss: 1.1557 - precision: 0.5588 - recall: 0.3941 - val_accuracy: 0.8482 - val_loss: 0.4385 - val_precision: 0.8683 - val_recall: 0.8299 - learning_rate: 1.0000e-04
# Epoch 2/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 80s 433ms/step - accuracy: 0.8360 - loss: 0.5132 - precision: 0.8730 - recall: 0.7749 - val_accuracy: 0.8604 - val_loss: 0.3763 - val_precision: 0.8745 - val_recall: 0.8452 - learning_rate: 1.0000e-04
# Epoch 3/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.8872 - loss: 0.3708 - precision: 0.9084 - recall: 0.8566 - val_accuracy: 0.8932 - val_loss: 0.3183 - val_precision: 0.9077 - val_recall: 0.8772 - learning_rate: 1.0000e-04
# Epoch 4/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 81s 434ms/step - accuracy: 0.9123 - loss: 0.2994 - precision: 0.9251 - recall: 0.8937 - val_accuracy: 0.9115 - val_loss: 0.2768 - val_precision: 0.9200 - val_recall: 0.9031 - learning_rate: 1.0000e-04
# Epoch 5/5
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 79s 424ms/step - accuracy: 0.9210 - loss: 0.2870 - precision: 0.9299 - recall: 0.9042 - val_accuracy: 0.8749 - val_loss: 0.3727 - val_precision: 0.8833 - val_recall: 0.8658 - learning_rate: 1.0000e-04
# Best hyperparameters: {'learning_rate': 0.0001, 'dropout_rate': 0.3, 'embed_dim': 512, 'num_heads': 4}
